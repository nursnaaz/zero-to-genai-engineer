# %%
import os
from openai import OpenAI

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=os.environ.get("OPENROUTER_API_KEY", ""),
)

# First API call with reasoning
response = client.chat.completions.create(
  model="nvidia/nemotron-3-super-120b-a12b:free",
  messages=[
          {
            "role": "user",
            "content": "How many r's are in the word 'strawberry'?"
          }
        ],
  extra_body={"reasoning": {"enabled": True}}
)

# Extract the assistant message with reasoning_details
response = response.choices[0].message

print(response)
# Out:
# ChatCompletionMessage(content='There are **3** r’s in the word “strawberry.”', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, reasoning='The user asks: "How many r\'s are in the word \'strawberry\'?" Need to count r\'s. The word "strawberry": letters: s t r a w b e r r y. Actually let\'s break: s (1), t (2), r (3), a (4), w (5), b (6), e (7), r (8), r (9), y (10). So there are 3 r\'s. Answer: 3.\n\n', reasoning_details=[{'type': 'reasoning.text', 'text': 'The user asks: "How many r\'s are in the word \'strawberry\'?" Need to count r\'s. The word "strawberry": letters: s t r a w b e r r y. Actually let\'s break: s (1), t (2), r (3), a (4), w (5), b (6), e (7), r (8), r (9), y (10). So there are 3 r\'s. Answer: 3.\n\n', 'format': 'unknown', 'index': 0}])
